# %%
import gensim

# %%
import numpy as np

# %%
import pandas as pd

# %%
import nltk

# %%
from nltk import word_tokenize,sent_tokenize

# %%
from nltk.corpus import stopwords

# %%
from gensim.utils import simple_preprocess

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stop_words = stopwords.words('english')

# %%
def pre_process(sent):
  words = word_tokenize(sent)
  words = [w for w in words if w not in stop_words]
  sent = " ".join(words)
  return sent

# %%
import os
story = []
for file in os.listdir(dir):
  f = open(os.path.join(dir,file),mode="r",encoding = 'latin-1')
  corpus = f.read()
  sents = sent_tokenize(corpus)
  for sent in sents:
    sent = pre_process(sent)
    story.append(simple_preprocess(sent))

# %%
print(story)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
story
# Out:
# [['george',
#   'martin',
#   'dance',
#   'with',
#   'dragons',
#   'book',
#   'five',
#   'song',
#   'ice',
#   'fire',
#   'dedication',
#   'one',
#   'fans',
#   'lodey',
#   'trebla',
#   'stego',
#   'pod',
#   'caress',
#   'yags',
#   'ray',
#   'mr',
#   'kate',
#   'chataya',
#   'mormont',
#   'mich',
#   'jamie',
#   'vanessa',
#   'ro',
#   'stubby',
#   'louise',
#   'agravaine',
#   'wert',
#   'malt',
#   'jo',
#   'mouse',
#   'telisiane',
#   'blackfyre',
#   'bronn',
#   'stone',
#   'coyote',
#   'daughter',
#   'rest',
#   'madmen',
#   'wild',
#   'women',
#   'brotherhood',
#   'without',
#   'banners',
#   'website',
#   'wizards',
#   'elio',
#   'linda',
#   'lords',
#   'westeros',
#   'winter',
#   'fabio',
#   'wic',
#   'gibbs',
#   'dragonstone',
#   'started',
#   'men',
#   'women',
#   'asshai',
#   'spain',
#   'sang',
#   'us',
#   'bear',
#   'maiden',
#   'fair',
#   'fabulous',
#   'fans',
#   'italy',
#   'gave',
#   'much',
#   'wine',
#   'readers',
#   'finland',
#   'germany',
#   'brazil',
#   'portugal',
#   'france',
#   'netherlands',
#   'distant',
#   'lands',
#   'you',
#   've',
#   'waiting',
#   'dance',
#   'friends',
#   'fans',
#   'yet',
#   'meet',
#   'thanks',
#   'patience',
#   'contents',
#   'dedication',
#   'cavil',
#   'on',
#   'chronology',
#   'prologue',
#   'tyrion',
#   'daenerys',
#   'jon',
#   'bran',
#   'tyrion',
#   'the',
#   'merchant',
#   'man',
#   'jon',
#   'tyrion',
#   'davos',
#   'jon',
#   'daenerys',
#   'reek',
#   'bran',
#   'tyrion',
#   'davos',
#   'daenerys',
#   'jon',
#   'tyrion',
#   'davos',
#   'reek',
#   'jon',
#   'tyrion',
#   'daenerys',
#   'the',
#   'lost',
#   'lord',
#   'the',
#   'windblown',
#   'the',
#   'wayward',
#   'bride',
#   'tyrion',
#   'jon',
#   'davos',
#   'daenerys',
#   'melisandre',
#   'reek',
#   'tyrion',
#   'bran',
#   'jon',
#   'daenerys',
#   'the',
#   'prince',
#   'of',
#   'winterfell',
#   'the',
#   'watcher',
#   'jon',
#   'tyrion',
#   'the',
#   'turncloak',
#   'the',
#   'king',
#   'prize',
#   'daenerys',
#   'jon',
#   'the',
#   'blind',
#   'girl',
#   'ghost',
#   'in',
#   'winterfell',
#   'tyrion',
#   'jaime',
#   'jon',
#   'daenerys',
#   'theon',
#   'daenerys',
#   'jon',
#   'cersei',
#   'the',
#   'queensguard',
#   'the',
#   'iron',
#   'suitor',
#   'tyrion',
#   'jon',
#   'the',
#   'discarded',
#   'knight',
#   'the',
#   'spurned',
#   'suitor',
#   'the',
#   'griffin',
#   'reborn',
#   'the',
#   'sacrifice',
#   'victarion',
#   'the',
#   'ugly',
#   'little',
#   'girl',
#   'cersei',
#   'tyrion',
#   'the',
#   'kingbreaker',
#   'the',
#   'dragontamer',
#   'jon',
#   'the',
#   'queen',
#   'hand',
#   'daenerys',
#   'epilogue',
#   'westeros',
#   'the',
#   'boy',
#   'king',
#   'the',
#   'king',
#   'at',
#   'the',
#   'wall',
#   'king',
#   'of',
#   'the',
#   'isles',
#   'and',
#   'the',
#   'north',
#   'other',
#   'houses',
#   'great',
#   'and',
#   'small',
#   'house',
#   'arryn',
#   'house',
#   'baratheon',
#   'house',
#   'frey',
#   'house',
#   'lannister',
#   'house',
#   'martell',
#   'house',
#   'stark',
#   'house',
#   'tully',
#   'house',
#   'tyrell',
#   'the',
#   'sworn',
#   'brothers',
#   'of',
#   'the',
#   'night',
#   'watch',
#   'wildlings',
#   'the',
#   'free',
#   'folk',
#   'beyond',
#   'the',
#   'wall',
#   'essos',
#   'beyond',
#   'the',
#   'narrow',
#   'sea',
#   'in',
#   'braavos',
#   'in',
#   'old',
#   'volantis',
#   'on',
#   'slaver',
#   'bay',
#   'the',
#   'queen',
#   'across',
#   'the',
#   'water',
#   'the',
#   'sellswords',
#   'men',
#   'and',
#   'women',
#   'of',
#   'the',
#   'free',
#   'companies',
#   'acknowledgments',
#   'about',
#   'author',
#   'about',
#   'type',
#   'by',
#   'george',
#   'martin',
#   'copyright',
#   'cavil',
#   'on',
#   'chronology',
#   'it',
#   'books',
#   'know'],
#  ['so', 'reminder', 'may', 'order'],
#  ['the', 'book', 'hold', 'hands', 'fifth', 'volume', 'song', 'ice', 'fire'],
#  ['the', 'fourth', 'volume', 'feast', 'crows'],
#  ['however',
#   'volume',
#   'follow',
#   'one',
#   'traditional',
#   'sense',
#   'much',
#   'run',
#   'tandem'],
#  ['both',
#   'dance',
#   'feast',
#   'take',
#   'story',
#   'immediately',
#   'events',
#   'third',
#   'volume',
#   'series',
#   'storm',
#   'swords'],
#  ['whereas',
#   'feast',
#   'focused',
#   'events',
#   'around',
#   'king',
#   'landing',
#   'iron',
#   'islands',
#   'dorne',
#   'dance',
#   'takes',
#   'us',
#   'north',
#   'castle',
#   'black',
#   'wall',
#   'beyond',
#   'across',
#   'narrow',
#   'sea',
#   'pentos',
#   'slaver',
#   'bay',
#   'pick',
#   'tales',
#   'tyrion',
#   'lannister',
#   'jon',
#   'snow',
#   'daenerys',
#   'targaryen',
#   'characters',
#   'see',
#   'preceding',
#   'volume'],
#  ['rather',
#   'sequential',
#   'two',
#   'books',
#   'parallel',
#   'divided',
#   'geographically',
#   'rather',
#   'chronologically'],
#  ['but', 'point'],
#  ['dance',
#   'dragons',
#   'longer',
#   'book',
#   'feast',
#   'crows',
#   'covers',
#   'longer',
#   'time',
#   'period'],
#  ['in',
#   'latter',
#   'half',
#   'volume',
#   'notice',
#   'certain',
#   'viewpoint',
#   'characters',
#   'feast',
#   'crows',
#   'popping'],
#  ['and',
#   'means',
#   'think',
#   'means',
#   'narrative',
#   'moved',
#   'past',
#   'time',
#   'frame',
#   'feast',
#   'two',
#   'streams',
#   'rejoined'],
#  ['next', 'the', 'winds', 'winter'],
#  ['wherein',
#   'hope',
#   'everybody',
#   'shivering',
#   'together',
#   'george',
#   'martin',
#   'april',
#   'prologue',
#   'the',
#   'night',
#   'rank',
#   'smell',
#   'man'],
#  ['the',
#   'warg',
#   'stopped',
#   'beneath',
#   'tree',
#   'sniffed',
#   'grey',
#   'brown',
#   'fur',
#   'dappled',
#   'shadow'],
#  ['sigh',
#   'piney',
#   'wind',
#   'brought',
#   'man',
#   'scent',
#   'fainter',
#   'smells',
#   'spoke',
#   'fox',
#   'hare',
#   'seal',
#   'stag',
#   'even',
#   'wolf'],
#  ['those',
#   'man',
#   'smells',
#   'warg',
#   'knew',
#   'stink',
#   'old',
#   'skins',
#   'dead',
#   'sour',
#   'near',
#   'drowned',
#   'beneath',
#   'stronger',
#   'scents',
#   'smoke',
#   'blood',
#   'rot'],
#  ['only', 'man', 'stripped', 'skins', 'beasts', 'wore', 'hides', 'hair'],
#  ['wargs', 'fear', 'man', 'wolves'],
#  ['hate',
#   'hunger',
#   'coiled',
#   'belly',
#   'gave',
#   'low',
#   'growl',
#   'calling',
#   'one',
#   'eyed',
#   'brother',
#   'small',
#   'sly',
#   'sister'],
#  ['as', 'raced', 'trees', 'packmates', 'followed', 'hard', 'heels'],
#  ['they', 'caught', 'scent', 'well'],
#  ['as', 'ran', 'saw', 'eyes', 'glimpsed', 'ahead'],
#  ['the', 'breath', 'pack', 'puffed', 'warm', 'white', 'long', 'grey', 'jaws'],
#  ['ice', 'frozen', 'paws', 'hard', 'stone', 'hunt', 'prey', 'ahead'],
#  ['flesh', 'warg', 'thought', 'meat'],
#  ['man', 'alone', 'feeble', 'thing'],
#  ['big', 'strong', 'good', 'sharp', 'eyes', 'dull', 'ear', 'deaf', 'smells'],
#  ['deer',
#   'elk',
#   'even',
#   'hares',
#   'faster',
#   'bears',
#   'boars',
#   'fiercer',
#   'fight'],
#  ['but', 'men', 'packs', 'dangerous'],
#  ['as',
#   'wolves',
#   'closed',
#   'prey',
#   'warg',
#   'heard',
#   'wailing',
#   'pup',
#   'crust',
#   'last',
#   'night',
#   'snow',
#   'breaking',
#   'clumsy',
#   'man',
#   'paws',
#   'rattle',
#   'hardskins',
#   'long',
#   'grey',
#   'claws',
#   'men',
#   'carried'],
#  ['swords', 'voice', 'inside', 'whispered', 'spears'],
#  ['the',
#   'trees',
#   'grown',
#   'icy',
#   'teeth',
#   'snarling',
#   'bare',
#   'brown',
#   'branches'],
#  ['one', 'eye', 'ripped', 'undergrowth', 'spraying', 'snow'],
#  ['his', 'packmates', 'followed'],
#  ['up', 'hill', 'slope', 'beyond', 'wood', 'opened', 'men'],
#  ['one', 'female'],
#  ['the', 'fur', 'wrapped', 'bundle', 'clutched', 'pup'],
#  ['leave', 'last', 'voice', 'whispered', 'males', 'danger'],
#  ['they', 'roaring', 'men', 'warg', 'could', 'smell', 'terror'],
#  ['one', 'wooden', 'tooth', 'tall'],
#  ['he', 'flung', 'hand', 'shaking', 'tooth', 'sailed', 'high'],
#  ['then', 'pack'],
#  ['his',
#   'one',
#   'eyed',
#   'brother',
#   'knocked',
#   'tooth',
#   'thrower',
#   'back',
#   'snowdrift',
#   'tore',
#   'throat',
#   'struggled'],
#  ['his', 'sister', 'slipped', 'behind', 'male', 'took', 'rear'],
#  ['that', 'left', 'female', 'pup'],
#  ['she',
#   'tooth',
#   'little',
#   'one',
#   'made',
#   'bone',
#   'dropped',
#   'warg',
#   'jaws',
#   'closed',
#   'around',
#   'leg'],
#  ['as', 'fell', 'wrapped', 'arms', 'around', 'noisy', 'pup'],
#  ['underneath', 'furs', 'female', 'skin', 'bones', 'dugs', 'full', 'milk'],
#  ['the', 'sweetest', 'meat', 'pup'],
#  ['the', 'wolf', 'saved', 'choicest', 'parts', 'brother'],
#  ['all',
#   'around',
#   'carcasses',
#   'frozen',
#   'snow',
#   'turned',
#   'pink',
#   'red',
#   'pack',
#   'filled',
#   'bellies'],
#  ['leagues',
#   'away',
#   'one',
#   'room',
#   'hut',
#   'mud',
#   'straw',
#   'thatched',
#   'roof',
#   'smoke',
#   'hole',
#   'floor',
#   'hard',
#   'packed',
#   'earth',
#   'varamyr',
#   'shivered',
#   'coughed',
#   'licked',
#   'lips'],
#  ['his',
#   'eyes',
#   'red',
#   'lips',
#   'cracked',
#   'throat',
#   'dry',
#   'parched',
#   'taste',
#   'blood',
#   'fat',
#   'filled',
#   'mouth',
#   'even',
#   'swollen',
#   'belly',
#   'cried',
#   'nourishment'],
#  ['child', 'flesh', 'thought', 'remembering', 'bump'],
#  ['human', 'meat'],
#  ['had', 'sunk', 'low', 'hunger', 'human', 'meat'],
#  ['he', 'could', 'almost', 'hear', 'haggon', 'growling'],
#  ['men',
#   'may',
#   'eat',
#   'flesh',
#   'beasts',
#   'beasts',
#   'flesh',
#   'men',
#   'man',
#   'eats',
#   'flesh',
#   'man',
#   'abomination',
#   'abomination'],
#  ['that', 'always', 'haggon', 'favorite', 'word'],
#  ['abomination', 'abomination', 'abomination'],
#  ['to',
#   'eat',
#   'human',
#   'meat',
#   'abomination',
#   'mate',
#   'wolf',
#   'wolf',
#   'abomination',
#   'seize',
#   'body',
#   'another',
#   'man',
#   'worst',
#   'abomination'],
#  ['haggon', 'weak', 'afraid', 'power'],
#  ['he', 'died', 'weeping', 'alone', 'ripped', 'second', 'life'],
#  ['varamyr', 'devoured', 'heart'],
#  ['he',
#   'taught',
#   'much',
#   'last',
#   'thing',
#   'learned',
#   'taste',
#   'human',
#   'flesh'],
#  ['that', 'wolf', 'though'],
#  ['he', 'never', 'eaten', 'meat', 'men', 'human', 'teeth'],
#  ['he', 'would', 'grudge', 'pack', 'feast', 'however'],
#  ['the',
#   'wolves',
#   'famished',
#   'gaunt',
#   'cold',
#   'hungry',
#   'prey',
#   'two',
#   'men',
#   'woman',
#   'babe',
#   'arms',
#   'fleeing',
#   'defeat',
#   'death'],
#  ['they', 'would', 'perished', 'soon', 'case', 'exposure', 'starvation'],
#  ['this', 'way', 'better', 'quicker'],
#  ['mercy'],
#  ['mercy', 'said', 'aloud'],
#  ['his', 'throat', 'raw', 'felt', 'good', 'hear', 'human', 'voice', 'even'],
#  ['the',
#   'air',
#   'smelled',
#   'mold',
#   'damp',
#   'ground',
#   'cold',
#   'hard',
#   'fire',
#   'giving',
#   'smoke',
#   'heat'],
#  ['he',
#   'moved',
#   'close',
#   'flames',
#   'dared',
#   'coughing',
#   'shivering',
#   'turns',
#   'side',
#   'throbbing',
#   'wound',
#   'opened'],
#  ['blood', 'soaked', 'breeches', 'knee', 'dried', 'hard', 'brown', 'crust'],
#  ['thistle', 'warned', 'might', 'happen'],
#  ['sewed',
#   'best',
#   'could',
#   'she',
#   'said',
#   'but',
#   'need',
#   'rest',
#   'let',
#   'mend',
#   'flesh',
#   'tear',
#   'open',
#   'again',
#   'thistle',
#   'last',
#   'companions',
#   'spearwife',
#   'tough',
#   'old',
#   'root',
#   'warty',
#   'windburnt',
#   'wrinkled'],
#  ['the', 'others', 'deserted', 'along', 'way'],
#  ['one',
#   'one',
#   'fell',
#   'behind',
#   'forged',
#   'ahead',
#   'making',
#   'old',
#   'villages',
#   'milkwater',
#   'hardhome',
#   'lonely',
#   'death',
#   'woods'],
#  ['varamyr', 'know', 'could', 'care'],
#  ['taken', 'one', 'chance'],
#  ['one', 'twins', 'big', 'man', 'scarred', 'face', 'youth', 'red', 'hair'],
#  ['he', 'afraid', 'though'],
#  ['one', 'others', 'might', 'realized', 'happening'],
#  ['then', 'would', 'turned', 'killed'],
#  ['and', 'haggon', 'words', 'haunted', 'chance', 'passed'],
#  ['after',
#   'battle',
#   'thousands',
#   'struggling',
#   'forest',
#   'hungry',
#   'frightened',
#   'fleeing',
#   'carnage',
#   'descended',
#   'wall'],
#  ['some',
#   'talked',
#   'returning',
#   'homes',
#   'they',
#   'abandoned',
#   'others',
#   'mounting',
#   'second',
#   'assault',
#   'upon',
#   'gate',
#   'lost',
#   'notion',
#   'go'],
#  ['they',
#   'escaped',
#   'black',
#   'cloaked',
#   'crows',
#   'knights',
#   'grey',
#   'steel',
#   'relentless',
#   'enemies',
#   'stalked'],
#  ['every', 'day', 'left', 'corpses', 'trails'],
#  ['some', 'died', 'hunger', 'cold', 'sickness'],
#  ['others',
#   'slain',
#   'brothers',
#   'in',
#   'arms',
#   'marched',
#   'south',
#   'mance',
#   'rayder',
#   'king',
#   'beyond',
#   'the',
#   'wall'],
#  ['mance',
#   'fallen',
#   'survivors',
#   'told',
#   'despairing',
#   'voices',
#   'mance',
#   'taken',
#   'mance',
#   'dead'],
#  ['harma',
#   'dead',
#   'mance',
#   'captured',
#   'rest',
#   'run',
#   'left',
#   'us',
#   'thistle',
#   'claimed',
#   'sewing',
#   'wound'],
#  ['tormund', 'weeper', 'sixskins', 'brave', 'raiders'],
#  ['where', 'she', 'know', 'varamyr', 'realized'],
#  ['without', 'beasts', 'look', 'like', 'great', 'man'],
#  ['varamyr', 'six', 'skins', 'broke', 'bread', 'mance', 'rayder'],
#  ['he', 'named', 'varamyr', 'ten'],
#  ['name', 'fit', 'lord', 'name', 'songs', 'mighty', 'name', 'fearsome'],
#  ['yet', 'run', 'crows', 'like', 'frightened', 'rabbit'],
#  ['the',
#   'terrible',
#   'lord',
#   'varamyr',
#   'gone',
#   'craven',
#   'could',
#   'bear',
#   'know',
#   'told',
#   'spearwife',
#   'name',
#   'haggon'],
#  ['afterward', 'wondered', 'name', 'come', 'lips', 'might', 'chosen'],
#  ['ate', 'heart', 'drank', 'blood', 'still', 'haunts'],
#  ['one',
#   'day',
#   'fled',
#   'rider',
#   'came',
#   'galloping',
#   'woods',
#   'gaunt',
#   'white',
#   'horse',
#   'shouting',
#   'make',
#   'milkwater',
#   'weeper',
#   'gathering',
#   'warriors',
#   'cross',
#   'bridge',
#   'skulls',
#   'take',
#   'shadow',
#   'tower'],
#  ['many', 'followed'],
#  ['later',
#   'dour',
#   'warrior',
#   'fur',
#   'amber',
#   'went',
#   'cookfire',
#   'cookfire',
#   'urging',
#   'survivors',
#   'head',
#   'north',
#   'take',
#   'refuge',
#   'valley',
#   'thenns'],
#  ['why',
#   'thought',
#   'would',
#   'safe',
#   'thenns',
#   'fled',
#   'place',
#   'varamyr',
#   'never',
#   'learned',
#   'hundreds',
#   'followed'],
#  ['hundreds',
#   'went',
#   'woods',
#   'witch',
#   'who',
#   'vision',
#   'fleet',
#   'ships',
#   'coming',
#   'carry',
#   'free',
#   'folk',
#   'south'],
#  ['we',
#   'must',
#   'seek',
#   'sea',
#   'cried',
#   'mother',
#   'mole',
#   'followers',
#   'turned',
#   'east'],
#  ['varamyr', 'might', 'amongst', 'he', 'stronger'],
#  ['the',
#   'sea',
#   'grey',
#   'cold',
#   'far',
#   'away',
#   'though',
#   'knew',
#   'would',
#   'never',
#   'live',
#   'see'],
#  ['he', 'nine', 'times', 'dead', 'dying', 'would', 'true', 'death'],
#  ['squirrel',
#   'skin',
#   'cloak',
#   'remembered',
#   'knifed',
#   'squirrel',
#   'skin',
#   'cloak'],
#  ['its',
#   'owner',
#   'dead',
#   'back',
#   'head',
#   'smashed',
#   'red',
#   'pulp',
#   'flecked',
#   'bits',
#   'bone',
#   'cloak',
#   'looked',
#   'warm',
#   'thick'],
#  ['it', 'snowing', 'varamyr', 'lost', 'cloaks', 'wall'],
#  ['his',
#   'sleeping',
#   'pelts',
#   'woolen',
#   'smallclothes',
#   'sheepskin',
#   'boots',
#   'fur',
#   'lined',
#   'gloves',
#   'store',
#   'mead',
#   'hoarded',
#   'food',
#   'hanks',
#   'hair',
#   'took',
#   'women',
#   'bedded',
#   'even',
#   'golden',
#   'arm',
#   'rings',
#   'mance',
#   'given',
#   'lost',
#   'left',
#   'behind'],
#  ['burned', 'died', 'ran', 'half', 'mad', 'pain', 'terror'],
#  ['the', 'memory', 'still', 'shamed', 'alone'],
#  ['others', 'run', 'well', 'hundreds', 'thousands'],
#  ['the', 'battle', 'lost'],
#  ['the',
#   'knights',
#   'come',
#   'invincible',
#   'steel',
#   'killing',
#   'everyone',
#   'stayed',
#   'fight'],
#  ['it', 'run', 'die'],
#  ['death', 'easily', 'outrun', 'however'],
#  ['so',
#   'varamyr',
#   'came',
#   'upon',
#   'dead',
#   'woman',
#   'wood',
#   'knelt',
#   'strip',
#   'cloak',
#   'never',
#   'saw',
#   'boy',
#   'burst',
#   'hiding',
#   'drive',
#   'long',
#   'bone',
#   'knife',
#   'side',
#   'rip',
#   'cloak',
#   'clutching',
#   'fingers'],
#  ['his', 'mother', 'thistle', 'told', 'later', 'boy', 'run'],
#  ['it',
#   'mother',
#   'cloak',
#   'saw',
#   'robbing',
#   'she',
#   'dead',
#   'varamyr',
#   'said',
#   'wincing',
#   'bone',
#   'needle',
#   'pierced',
#   'flesh'],
#  ['someone', 'smashed', 'head'],
#  ['some', 'crow', 'no', 'crow'],
#  ['hornfoot', 'men'],
#  ['saw', 'it', 'her', 'needle', 'pulled', 'gash', 'side', 'closed'],
#  ['savages', 'who', 'left', 'tame', 'no', 'one'],
#  ['if', 'mance', 'dead', 'free', 'folk', 'doomed'],
#  ['the',
#   'thenns',
#   'giants',
#   'hornfoot',
#   'men',
#   'cave',
#   'dwellers',
#   'filed',
#   'teeth',
#   'men',
#   'western',
#   'shore',
#   'chariots',
#   'bone',
#   'doomed',
#   'well'],
#  ['even', 'crows'],
#  ['they',
#   'might',
#   'know',
#   'yet',
#   'black',
#   'cloaked',
#   'bastards',
#   'would',
#   'perish',
#   'rest'],
#  ['the', 'enemy', 'coming'],
#  ['haggon', 'rough', 'voice', 'echoed', 'head'],
#  ['you',
#   'die',
#   'dozen',
#   'deaths',
#   'boy',
#   'every',
#   'one',
#   'hurt',
#   'true',
#   'death',
#   'comes',
#   'live'],
#  ['the',
#   'second',
#   'life',
#   'simpler',
#   'sweeter',
#   'say',
#   'varamyr',
#   'sixskins',
#   'would',
#   'know',
#   'truth',
#   'soon',
#   'enough'],
#  ['he',
#   'could',
#   'taste',
#   'true',
#   'death',
#   'smoke',
#   'hung',
#   'acrid',
#   'air',
#   'feel',
#   'heat',
#   'beneath',
#   'fingers',
#   'slipped',
#   'hand',
#   'clothes',
#   'touch',
#   'wound'],
#  ['the', 'chill', 'though', 'deep', 'bones'],
#  ['this', 'time', 'would', 'cold', 'killed'],
#  ['his', 'last', 'death', 'fire'],
#  ['burned'],
#  ['at',
#   'first',
#   'confusion',
#   'thought',
#   'archer',
#   'wall',
#   'pierced',
#   'flaming',
#   'arrow',
#   'fire',
#   'inside',
#   'consuming'],
#  ['and', 'pain', 'varamyr', 'died', 'nine', 'times'],
#  ['he',
#   'died',
#   'spear',
#   'thrust',
#   'bear',
#   'teeth',
#   'throat',
#   'wash',
#   'blood',
#   'brought',
#   'forth',
#   'stillborn',
#   'cub'],
#  ['he', 'died', 'first', 'death', 'six', 'father', 'axe', 'crashed', 'skull'],
#  ['even',
#   'agonizing',
#   'fire',
#   'guts',
#   'crackling',
#   'along',
#   'wings',
#   'devouring'],
#  ['when',
#   'tried',
#   'fly',
#   'terror',
#   'fanned',
#   'flames',
#   'made',
#   'burn',
#   'hotter'],
#  ['one',
#   'moment',
#   'soaring',
#   'wall',
#   'eagle',
#   'eyes',
#   'marking',
#   'movements',
#   'men'],
#  ['then',
#   'flames',
#   'turned',
#   'heart',
#   'blackened',
#   'cinder',
#   'sent',
#   'spirit',
#   'screaming',
#   'back',
#   'skin',
#   'little',
#   'he',
#   'gone',
#   'mad'],
#  ['even', 'memory', 'enough', 'make', 'shudder'],
#  ['that', 'noticed', 'fire', 'gone'],
#  ['only',
#   'grey',
#   'and',
#   'black',
#   'tangle',
#   'charred',
#   'wood',
#   'remained',
#   'embers',
#   'glowing',
#   'ashes'],
#  ['there', 'still', 'smoke', 'needs', 'wood'],
#  ['gritting',
#   'teeth',
#   'pain',
#   'varamyr',
#   'crept',
#   'pile',
#   'broken',
#   'branches',
#   'thistle',
#   'gathered',
#   'went',
#   'hunting',
#   'tossed',
#   'sticks',
#   'onto',
#   'ashes'],
#  ['catch', 'croaked'],
#  ['burn',
#   'he',
#   'blew',
#   'upon',
#   'embers',
#   'said',
#   'wordless',
#   'prayer',
#   'nameless',
#   'gods',
#   'wood',
#   'hill',
#   'field'],
#  ['the', 'gods', 'gave', 'answer'],
#  ['after', 'smoke', 'ceased', 'rise', 'well'],
#  ['already', 'little', 'hut', 'growing', 'colder'],
#  ['varamyr', 'flint', 'tinder', 'dry', 'kindling'],
#  ['he', 'would', 'never', 'get', 'fire', 'burning'],
#  ['thistle', 'called', 'voice', 'hoarse', 'edged', 'pain'],
#  ['thistle',
#   'her',
#   'chin',
#   'pointed',
#   'nose',
#   'flat',
#   'mole',
#   'one',
#   'cheek',
#   'four',
#   'dark',
#   'hairs',
#   'growing'],
#  ['an',
#   'ugly',
#   'face',
#   'hard',
#   'yet',
#   'would',
#   'given',
#   'much',
#   'glimpse',
#   'door',
#   'hut'],
#  ['taken', 'left'],
#  ['how', 'long', 'gone'],
#  ['two', 'days'],
#  ['three'],
#  ['varamyr', 'uncertain'],
#  ['it',
#   'dark',
#   'inside',
#   'hut',
#   'drifting',
#   'sleep',
#   'never',
#   'quite',
#   'sure',
#   'day',
#   'night',
#   'outside'],
#  ['wait', 'she', 'said'],
#  ['back',
#   'food',
#   'so',
#   'like',
#   'fool',
#   'he',
#   'waited',
#   'dreaming',
#   'haggon',
#   'bump',
#   'wrongs',
#   'done',
#   'long',
#   'life',
#   'days',
#   'nights',
#   'passed',
#   'thistle',
#   'returned'],
#  ['she', 'won', 'coming', 'back'],
#  ['varamyr', 'wondered', 'given', 'away'],
#  ['could', 'tell', 'thinking', 'looking', 'muttered', 'fever', 'dream'],
#  ['abomination', 'heard', 'haggon', 'saying'],
#  ['it', 'almost', 'room'],
#  ['she', 'ugly', 'spearwife', 'varamyr', 'told'],
#  ['great', 'man'],
#  ['varamyr',
#   'warg',
#   'skinchanger',
#   'right',
#   'live',
#   'die',
#   'no',
#   'one',
#   'answered'],
#  ['there', 'one'],
#  ['thistle', 'gone'],
#  ['she', 'abandoned', 'rest'],
#  ['his', 'mother', 'abandoned', 'well'],
#  ['she', 'cried', 'bump', 'never', 'cried'],
#  ['the',
#   'morning',
#   'father',
#   'pulled',
#   'bed',
#   'deliver',
#   'haggon',
#   'would',
#   'even',
#   'look'],
#  ['he',
#   'shrieked',
#   'kicked',
#   'dragged',
#   'woods',
#   'father',
#   'slapped',
#   'told',
#   'quiet'],
#  ['you', 'belong', 'kind', 'said', 'flung', 'haggon', 'feet'],
#  ['he', 'wrong', 'varamyr', 'thought', 'shivering'],
#  ['haggon', 'taught', 'much'],
#  ['he',
#   'taught',
#   'hunt',
#   'fish',
#   'butcher',
#   'carcass',
#   'bone',
#   'fish',
#   'find',
#   'way',
#   'woods'],
#  ['and',
#   'taught',
#   'way',
#   'warg',
#   'secrets',
#   'skinchanger',
#   'though',
#   'gift',
#   'stronger'],
#  ['years',
#   'later',
#   'tried',
#   'find',
#   'parents',
#   'tell',
#   'lump',
#   'become',
#   'great',
#   'varamyr',
#   'sixskins',
#   'dead',
#   'burned'],
#  ['gone', 'trees', 'streams', 'gone', 'rocks', 'earth'],
#  ['gone', 'dirt', 'ashes'],
#  ['that', 'woods', 'witch', 'told', 'mother', 'day', 'bump', 'died'],
#  ['lump', 'want', 'clod', 'earth'],
#  ['the',
#   'boy',
#   'dreamed',
#   'day',
#   'bards',
#   'would',
#   'sing',
#   'deeds',
#   'pretty',
#   'girls',
#   'would',
#   'kiss'],
#  ['when', 'grown', 'king', 'beyond', 'the', 'wall', 'lump', 'promised'],
#  ['he', 'never', 'come', 'close'],
#  ['varamyr', 'sixskins', 'name', 'men', 'feared'],
#  ['he',
#   'rode',
#   'battle',
#   'back',
#   'snow',
#   'bear',
#   'thirteen',
#   'feet',
#   'tall',
#   'kept',
#   'three',
#   'wolves',
#   'shadowcat',
#   'thrall',
#   'sat',
#   'right',
#   'hand',
#   'mance',
#   'rayder'],
#  ['it', 'mance', 'brought', 'place'],
#  ['listened'],
#  ['slipped', 'inside', 'bear', 'torn', 'pieces'],
#  ['before', 'mance', 'varamyr', 'sixskins', 'lord', 'sorts'],
#  ['he',
#   'lived',
#   'alone',
#   'hall',
#   'moss',
#   'mud',
#   'hewn',
#   'logs',
#   'haggon',
#   'attended',
#   'beasts'],
#  ['dozen',
#   'villages',
#   'homage',
#   'bread',
#   'salt',
#   'cider',
#   'offering',
#   'fruit',
#   'orchards',
#   'vegetables',
#   'gardens'],
#  ['his', 'meat', 'got'],
#  ['whenever',
#   'desired',
#   'woman',
#   'sent',
#   'shadowcat',
#   'stalk',
#   'whatever',
#   'girl',
#   'he',
#   'cast',
#   'eye',
#   'upon',
#   'would',
#   'follow',
#   'meekly',
#   'bed'],
#  ['some', 'came', 'weeping', 'aye', 'still', 'came'],
#  ['varamyr',
#   'gave',
#   'seed',
#   'took',
#   'hank',
#   'hair',
#   'remember',
#   'sent',
#   'back'],
#  ['from',
#   'time',
#   'time',
#   'village',
#   'hero',
#   'would',
#   'come',
#   'spear',
#   'hand',
#   'slay',
#   'beastling',
#   'save',
#   'sister',
#   'lover',
#   'daughter'],
#  ['those', 'killed', 'never', 'harmed', 'women'],
#  ['some', 'even', 'blessed', 'children'],
#  ['runts'],
#  ['small', 'puny', 'things', 'like', 'lump', 'one', 'gift'],
#  ['fear', 'drove', 'feet', 'reeling'],
#  ['holding',
#   'side',
#   'staunch',
#   'seep',
#   'blood',
#   'wound',
#   'varamyr',
#   'lurched',
#   'door',
#   'swept',
#   'aside',
#   'ragged',
#   'skin',
#   'covered',
#   'face',
#   'wall',
#   'white'],
#  ['snow'],
#  ['no', 'wonder', 'grown', 'dark', 'smoky', 'inside'],
#  ['the', 'falling', 'snow', 'buried', 'hut'],
#  ['when',
#   'varamyr',
#   'pushed',
#   'snow',
#   'crumbled',
#   'gave',
#   'way',
#   'still',
#   'soft',
#   'wet'],
#  ['outside',
#   'night',
#   'white',
#   'death',
#   'pale',
#   'thin',
#   'clouds',
#   'danced',
#   'attendance',
#   'silver',
#   'moon',
#   'thousand',
#   'stars',
#   'watched',
#   'coldly'],
#  ['he',
#   'could',
#   'see',
#   'humped',
#   'shapes',
#   'huts',
#   'buried',
#   'beneath',
#   'drifts',
#   'snow',
#   'beyond',
#   'pale',
#   'shadow',
#   'weirwood',
#   'armored',
#   'ice'],
#  ['to',
#   'south',
#   'west',
#   'hills',
#   'vast',
#   'white',
#   'wilderness',
#   'nothing',
#   'moved',
#   'except',
#   'blowing',
#   'snow'],
#  ['thistle',
#   'varamyr',
#   'called',
#   'feebly',
#   'wondering',
#   'far',
#   'could',
#   'gone'],
#  ['thistle'],
#  ['woman'],
#  ['where', 'far', 'away', 'wolf', 'gave', 'howl'],
#  ['shiver', 'went', 'varamyr'],
#  ['he', 'knew', 'howl', 'well', 'lump', 'known', 'mother', 'voice'],
#  ['one', 'eye'],
#  ['he', 'oldest', 'three', 'biggest', 'fiercest'],
#  ['stalker',
#   'leaner',
#   'quicker',
#   'younger',
#   'sly',
#   'cunning',
#   'went',
#   'fear',
#   'one',
#   'eye'],
#  ['the', 'old', 'wolf', 'fearless', 'relentless', 'savage'],
#  ['varamyr', 'lost', 'control', 'beasts', 'agony', 'eagle', 'death'],
#  ['his',
#   'shadowcat',
#   'raced',
#   'woods',
#   'whilst',
#   'snow',
#   'bear',
#   'turned',
#   'claws',
#   'around',
#   'ripping',
#   'apart',
#   'four',
#   'men',
#   'falling',
#   'spear'],
#  ['she', 'would', 'slain', 'varamyr', 'come', 'within', 'reach'],
#  ['the',
#   'bear',
#   'hated',
#   'raged',
#   'time',
#   'wore',
#   'skin',
#   'climbed',
#   'upon',
#   'back'],
#  ['his', 'wolves', 'though', 'my', 'brothers'],
#  ['my', 'pack'],
#  ['many',
#   'cold',
#   'night',
#   'slept',
#   'wolves',
#   'shaggy',
#   'bodies',
#   'piled',
#   'around',
#   'help',
#   'keep',
#   'warm'],
#  ['when',
#   'die',
#   'feast',
#   'upon',
#   'flesh',
#   'leave',
#   'bones',
#   'greet',
#   'thaw',
#   'come',
#   'spring'],
#  ['the', 'thought', 'queerly', 'comforting'],
#  ['his',
#   'wolves',
#   'often',
#   'foraged',
#   'roamed',
#   'seemed',
#   'fitting',
#   'feed',
#   'end'],
#  ['he',
#   'might',
#   'well',
#   'begin',
#   'second',
#   'life',
#   'tearing',
#   'warm',
#   'dead',
#   'flesh',
#   'corpse'],
#  ['dogs',
#   'easiest',
#   'beasts',
#   'bond',
#   'lived',
#   'close',
#   'men',
#   'almost',
#   'human'],
#  ['slipping',
#   'dog',
#   'skin',
#   'like',
#   'putting',
#   'old',
#   'boot',
#   'leather',
#   'softened',
#   'wear'],
#  ['as',
#   'boot',
#   'shaped',
#   'accept',
#   'foot',
#   'dog',
#   'shaped',
#   'accept',
#   'collar',
#   'even',
#   'collar',
#   'human',
#   'eye',
#   'could',
#   'see'],
#  ['wolves', 'harder'],
#  ['man',
#   'might',
#   'befriend',
#   'wolf',
#   'even',
#   'break',
#   'wolf',
#   'man',
#   'could',
#   'truly',
#   'tame',
#   'wolf'],
#  ['wolves', 'women', 'wed', 'life', 'haggon', 'often', 'said'],
#  ['you', 'take', 'one', 'that', 'marriage'],
#  ['the', 'wolf', 'part', 'day', 'you', 're', 'part'],
#  ['both',
#   'change',
#   'other',
#   'beasts',
#   'best',
#   'left',
#   'alone',
#   'hunter',
#   'declared'],
#  ['cats', 'vain', 'cruel', 'always', 'ready', 'turn'],
#  ['elk',
#   'deer',
#   'prey',
#   'wear',
#   'skins',
#   'long',
#   'even',
#   'bravest',
#   'man',
#   'became',
#   'coward'],
#  ['bears', 'boars', 'badgers', 'weasels', 'haggon', 'hold'],
#  ['some', 'skins', 'never', 'want', 'wear', 'boy'],
#  ['you', 'won', 'like', 'you', 'become', 'birds', 'worst', 'hear', 'tell'],
#  ['men', 'meant', 'leave', 'earth'],
#  ['spend', 'much', 'time', 'clouds', 'never', 'want', 'come', 'back'],
#  ['know', 'skinchangers', 'who', 've', 'tried', 'hawks', 'owls', 'ravens'],
#  ['even',
#   'skins',
#   'sit',
#   'moony',
#   'staring',
#   'bloody',
#   'blue',
#   'not',
#   'skinchangers',
#   'felt',
#   'however'],
#  ['once', 'lump', 'ten', 'haggon', 'taken', 'gathering'],
#  ['the',
#   'wargs',
#   'numerous',
#   'company',
#   'wolf',
#   'brothers',
#   'boy',
#   'found',
#   'others',
#   'stranger',
#   'fascinating'],
#  ['borroq',
#   'looked',
#   'much',
#   'like',
#   'boar',
#   'lacked',
#   'tusks',
#   'orell',
#   'eagle',
#   'briar',
#   'shadowcat',
#   'moment',
#   'saw',
#   'lump',
#   'wanted',
#   'shadowcat',
#   'goat',
#   'woman',
#   'grisella',
#   'none',
#   'strong',
#   'varamyr',
#   'sixskins',
#   'though',
#   'even',
#   'haggon',
#   'tall',
#   'grim',
#   'hands',
#   'hard',
#   'stone'],
#  ['the',
#   'hunter',
#   'died',
#   'weeping',
#   'varamyr',
#   'took',
#   'greyskin',
#   'driving',
#   'claim',
#   'beast'],
#  ['no', 'second', 'life', 'old', 'man'],
#  ['varamyr', 'threeskins', 'he', 'called', 'back'],
#  ['greyskin',
#   'made',
#   'four',
#   'though',
#   'old',
#   'wolf',
#   'frail',
#   'almost',
#   'toothless',
#   'soon',
#   'followed',
#   'haggon',
#   'death'],
#  ['varamyr', 'could', 'take', 'beast', 'wanted', 'bend', 'make', 'flesh'],
#  ['dog', 'wolf', 'bear', 'badger', 'thistle', 'thought'],
#  ['haggon',
#   'would',
#   'call',
#   'abomination',
#   'blackest',
#   'sin',
#   'haggon',
#   'dead',
#   'devoured',
#   'burned'],
#  ['mance', 'would', 'cursed', 'well', 'mance', 'slain', 'captured'],
#  ['no', 'one', 'ever', 'know'],
#  ['thistle', 'spearwife', 'varamyr', 'sixskins', 'dead'],
#  ['his', 'gift', 'would', 'perish', 'body', 'expected'],
#  ['he',
#   'would',
#   'lose',
#   'wolves',
#   'live',
#   'rest',
#   'days',
#   'scrawny',
#   'warty',
#   'woman',
#   'would',
#   'live'],
#  ['if', 'comes', 'back'],
#  ['if', 'still', 'strong', 'enough', 'take'],
#  ['wave', 'dizziness', 'washed', 'varamyr'],
#  ['he', 'found', 'upon', 'knees', 'hands', 'buried', 'snowdrift'],
#  ['he',
#   'scooped',
#   'fistful',
#   'snow',
#   'filled',
#   'mouth',
#   'rubbing',
#   'beard',
#   'cracked',
#   'lips',
#   'sucking',
#   'moisture'],
#  ['the',
#   'water',
#   'cold',
#   'could',
#   'barely',
#   'bring',
#   'swallow',
#   'realized',
#   'hot'],
#  ['the', 'snowmelt', 'made', 'hungrier'],
#  ['it', 'food', 'belly', 'craved', 'water'],
#  ['the',
#   'snow',
#   'stopped',
#   'falling',
#   'wind',
#   'rising',
#   'filling',
#   'air',
#   'crystal',
#   'slashing',
#   'face',
#   'struggled',
#   'drifts',
#   'wound',
#   'side',
#   'opening',
#   'closing'],
#  ['his', 'breath', 'made', 'ragged', 'white', 'cloud'],
#  ['when',
#   'reached',
#   'weirwood',
#   'tree',
#   'found',
#   'fallen',
#   'branch',
#   'long',
#   'enough',
#   'use',
#   'crutch'],
#  ['leaning', 'heavily', 'upon', 'staggered', 'toward', 'nearest', 'hut'],
#  ['perhaps',
#   'villagers',
#   'forgotten',
#   'something',
#   'fled',
#   'sack',
#   'apples',
#   'dried',
#   'meat',
#   'anything',
#   'keep',
#   'alive',
#   'thistle',
#   'returned'],
#  ['he', 'almost', 'crutch', 'snapped', 'beneath', 'weight', 'legs', 'went'],
#  ['how',
#   'long',
#   'sprawled',
#   'blood',
#   'reddening',
#   'snow',
#   'varamyr',
#   'could',
#   'said'],
#  ['the', 'snow', 'bury'],
#  ['it', 'would', 'peaceful', 'death'],
#  ['they', 'say', 'feel', 'warm', 'near', 'end', 'warm', 'sleepy'],
#  ['it',
#   'would',
#   'good',
#   'feel',
#   'warm',
#   'though',
#   'made',
#   'sad',
#   'think',
#   'would',
#   'never',
#   'see',
#   'green',
#   'lands',
#   'warm',
#   'lands',
#   'beyond',
#   'wall',
#   'mance',
#   'used',
#   'sing'],
#  ['the', 'world', 'beyond', 'wall', 'kind', 'haggon', 'used', 'say'],
#  ['the', 'free', 'folk', 'fear', 'skinchangers', 'honor', 'us', 'well'],
#  ['south',
#   'wall',
#   'kneelers',
#   'hunt',
#   'us',
#   'butcher',
#   'us',
#   'like',
#   'pigs',
#   'you',
#   'warned',
#   'varamyr',
#   'thought',
#   'showed',
#   'eastwatch'],
#  ['he', 'could', 'ten'],
#  ['haggon',
#   'traded',
#   'dozen',
#   'strings',
#   'amber',
#   'sled',
#   'piled',
#   'high',
#   'pelts',
#   'six',
#   'skins',
#   'wine',
#   'block',
#   'salt',
#   'copper',
#   'kettle'],
#  ['eastwatch',
#   'better',
#   'place',
#   'trade',
#   'castle',
#   'black',
#   'ships',
#   'came',
#   'laden',
#   'goods',
#   'fabled',
#   'lands',
#   'beyond',
#   'sea'],
#  ['the',
#   'crows',
#   'knew',
#   'haggon',
#   'hunter',
#   'friend',
#   'night',
#   'watch',
#   'welcomed',
#   'news',
#   'brought',
#   'life',
#   'beyond',
#   'wall'],
#  ['some', 'knew', 'skinchanger', 'one', 'spoke'],
#  ['it',
#   'eastwatch',
#   'by',
#   'the',
#   'sea',
#   'boy',
#   'he',
#   'first',
#   'began',
#   'dream',
#   'warm',
#   'south'],
#  ['varamyr', 'could', 'feel', 'snowflakes', 'melting', 'brow'],
#  ['this', 'bad', 'burning'],
#  ['let', 'sleep', 'never', 'wake', 'let', 'begin', 'second', 'life'],
#  ['his', 'wolves', 'close'],
#  ['he', 'could', 'feel'],
#  ['he',
#   'would',
#   'leave',
#   'feeble',
#   'flesh',
#   'behind',
#   'become',
#   'one',
#   'hunting',
#   'night',
#   'howling',
#   'moon'],
#  ['the', 'warg', 'would', 'become', 'true', 'wolf'],
#  ['which', 'though'],
#  ['not', 'sly'],
#  ['haggon',
#   'would',
#   'called',
#   'abomination',
#   'varamyr',
#   'often',
#   'slipped',
#   'inside',
#   'skin',
#   'mounted',
#   'one',
#   'eye'],
#  ['he', 'want', 'spend', 'new', 'life', 'bitch', 'though', 'unless', 'choice'],
#  ['stalker',
#   'might',
#   'suit',
#   'better',
#   'younger',
#   'male',
#   'though',
#   'one',
#   'eye',
#   'larger',
#   'fiercer',
#   'one',
#   'eye',
#   'took',
#   'sly',
#   'whenever',
#   'went',
#   'heat'],
#  ['they', 'say', 'forget', 'haggon', 'told', 'weeks', 'death'],
#  ['when',
#   'man',
#   'flesh',
#   'dies',
#   'spirit',
#   'lives',
#   'inside',
#   'beast',
#   'every',
#   'day',
#   'memory',
#   'fades',
#   'beast',
#   'becomes',
#   'little',
#   'less',
#   'warg',
#   'little',
#   'wolf',
#   'nothing',
#   'man',
#   'left',
#   'beast',
#   'remains',
#   'varamyr',
#   'knew',
#   'truth'],
#  ['when',
#   'claimed',
#   'eagle',
#   'orell',
#   'could',
#   'feel',
#   'skinchanger',
#   'raging',
#   'presence'],
#  ['orell',
#   'slain',
#   'turncloak',
#   'crow',
#   'jon',
#   'snow',
#   'hate',
#   'killer',
#   'strong',
#   'varamyr',
#   'found',
#   'hating',
#   'beastling',
#   'boy',
#   'well'],
#  ['he',
#   'known',
#   'snow',
#   'moment',
#   'saw',
#   'great',
#   'white',
#   'direwolf',
#   'stalking',
#   'silent',
#   'side'],
#  ['one', 'skinchanger', 'always', 'sense', 'another'],
#  ['mance', 'let', 'take', 'direwolf'],
#  ['there', 'would', 'second', 'life', 'worthy', 'king'],
#  ['he', 'could', 'done', 'doubt'],
#  ['the',
#   'gift',
#   'strong',
#   'snow',
#   'youth',
#   'untaught',
#   'still',
#   'fighting',
#   'nature',
#   'gloried'],
#  ['varamyr',
#   'could',
#   'see',
#   'weirwood',
#   'red',
#   'eyes',
#   'staring',
#   'white',
#   'trunk'],
#  ['the', 'gods', 'weighing'],
#  ['shiver', 'went'],
#  ['he', 'done', 'bad', 'things', 'terrible', 'things'],
#  ['he', 'stolen', 'killed', 'raped'],
#  ['he',
#   'gorged',
#   'human',
#   'flesh',
#   'lapped',
#   'blood',
#   'dying',
#   'men',
#   'gushed',
#   'red',
#   'hot',
#   'torn',
#   'throats'],
#  ['he',
#   'stalked',
#   'foes',
#   'woods',
#   'fallen',
#   'slept',
#   'clawed',
#   'entrails',
#   'bellies',
#   'scattered',
#   'across',
#   'muddy',
#   'earth'],
#  ['how', 'sweet', 'meat', 'tasted'],
#  ['that', 'beast', 'said', 'hoarse', 'whisper'],
#  ['that', 'gift', 'gave', 'me', 'the', 'gods', 'made', 'reply'],
#  ['his', 'breath', 'hung', 'pale', 'misty', 'air'],
#  ['he', 'could', 'feel', 'ice', 'forming', 'beard'],
#  ['varamyr', 'sixskins', 'closed', 'eyes'],
#  ['he',
#   'dreamt',
#   'old',
#   'dream',
#   'hovel',
#   'sea',
#   'three',
#   'dogs',
#   'whimpering',
#   'woman',
#   'tears'],
#  ['bump'],
#  ['she', 'weeps', 'bump', 'never', 'wept'],
#  ['lump',
#   'born',
#   'month',
#   'proper',
#   'time',
#   'sick',
#   'often',
#   'one',
#   'expected',
#   'live'],
#  ['his',
#   'mother',
#   'waited',
#   'almost',
#   'four',
#   'give',
#   'proper',
#   'name',
#   'late'],
#  ['the',
#   'whole',
#   'village',
#   'taken',
#   'calling',
#   'lump',
#   'name',
#   'sister',
#   'meha',
#   'given',
#   'still',
#   'mother',
#   'belly'],
#  ['meha',
#   'given',
#   'bump',
#   'name',
#   'well',
#   'lump',
#   'little',
#   'brother',
#   'born',
#   'proper',
#   'time',
#   'big',
#   'red',
#   'robust',
#   'sucking',
#   'greedily',
#   'mother',
#   'teats'],
#  ['she', 'going', 'name', 'father'],
#  ['bump', 'died', 'though'],
#  ['he', 'died', 'two', 'six', 'three', 'days', 'nameday'],
#  ['your', 'little', 'one', 'gods', 'woods', 'witch', 'told', 'mother', 'wept'],
#  ['he', 'll', 'never', 'hurt', 'never', 'hunger', 'never', 'cry'],
#  ['the', 'gods', 'taken', 'earth', 'trees'],
#  ['the', 'gods', 'around', 'us', 'rocks', 'streams', 'birds', 'beasts'],
#  ['your', 'bump', 'gone', 'join'],
#  ['he',
#   'll',
#   'world',
#   'that',
#   'it',
#   'the',
#   'old',
#   'woman',
#   'words',
#   'gone',
#   'lump',
#   'like',
#   'knife'],
#  ['bump', 'sees'],
#  ['he', 'watching'],
#  ['he', 'knows'],
#  ['lump',
#   'could',
#   'hide',
#   'could',
#   'slip',
#   'behind',
#   'mother',
#   'skirts',
#   'run',
#   'dogs',
#   'escape',
#   'father',
#   'fury'],
#  ['the', 'dogs'],
#  ['loptail', 'sniff', 'growler'],
#  ['they', 'good', 'dogs'],
#  ['they', 'friends'],
#  ['when',
#   'father',
#   'found',
#   'dogs',
#   'sniffing',
#   'round',
#   'bump',
#   'body',
#   'way',
#   'knowing',
#   'done',
#   'took',
#   'axe',
#   'three'],
#  ['his',
#   'hands',
#   'shook',
#   'badly',
#   'took',
#   'two',
#   'blows',
#   'silence',
#   'sniff',
#   'four',
#   'put',
#   'growler'],
#  ['the',
#   'smell',
#   'blood',
#   'hung',
#   'heavy',
#   'air',
#   'sounds',
#   'dying',
#   'dogs',
#   'made',
#   'terrible',
#   'hear',
#   'yet',
#   'loptail',
#   'still',
#   'came',
#   'father',
#   'called'],
#  ['he', 'oldest', 'dog', 'training', 'overcame', 'terror'],
#  ['by', 'time', 'lump', 'slipped', 'inside', 'skin', 'late'],
#  ['no',
#   'father',
#   'please',
#   'tried',
#   'say',
#   'dogs',
#   'speak',
#   'tongues',
#   'men',
#   'emerged',
#   'piteous',
#   'whine'],
#  ['the',
#   'axe',
#   'crashed',
#   'middle',
#   'old',
#   'dog',
#   'skull',
#   'inside',
#   'hovel',
#   'boy',
#   'let',
#   'scream'],
#  ['that', 'knew'],
#  ['two', 'days', 'later', 'father', 'dragged', 'woods'],
#  ['he',
#   'brought',
#   'axe',
#   'lump',
#   'thought',
#   'meant',
#   'put',
#   'way',
#   'done',
#   'dogs'],
#  ['instead', 'he', 'given', 'haggon'],
#  ['varamyr', 'woke', 'suddenly', 'violently', 'whole', 'body', 'shaking'],
#  ['get', 'voice', 'screaming', 'get', 'go'],
#  ['there',
#   'hundreds',
#   'them',
#   'the',
#   'snow',
#   'covered',
#   'stiff',
#   'white',
#   'blanket'],
#  ['so', 'cold'],
#  ['when', 'tried', 'move', 'found', 'hand', 'frozen', 'ground'],
#  ['he', 'left', 'skin', 'behind', 'tore', 'loose'],
#  ['get', 'screamed', 'they', 're', 'coming', 'thistle', 'returned'],
#  ['she', 'shoulders', 'shaking', 'shouting', 'face'],
#  ['varamyr',
#   'could',
#   'smell',
#   'breath',
#   'feel',
#   'warmth',
#   'upon',
#   'cheeks',
#   'gone',
#   'numb',
#   'cold'],
#  ['now', 'thought', 'die'],
#  ['he', 'summoned', 'strength', 'still', 'leapt', 'skin', 'forced', 'inside'],
#  ['thistle', 'arched', 'back', 'screamed'],
#  ['abomination'],
#  ['was', 'haggon'],
#  ['he', 'never', 'knew'],
#  ['his', 'old', 'flesh', 'fell', 'back', 'snowdrift', 'fingers', 'loosened'],
#  ['the', 'spear', 'wife', 'twisted', 'violently', 'shrieking'],
#  ['his',
#   'shadowcat',
#   'used',
#   'fight',
#   'wildly',
#   'snow',
#   'bear',
#   'gone',
#   'half',
#   'mad',
#   'time',
#   'snapping',
#   'trees',
#   'rocks',
#   'empty',
#   'air',
#   'worse'],
#  ['get', 'get', 'heard', 'mouth', 'shouting'],
#  ['her',
#   'body',
#   'staggered',
#   'fell',
#   'rose',
#   'hands',
#   'flailed',
#   'legs',
#   'jerked',
#   'way',
#   'grotesque',
#   'dance',
#   'spirit',
#   'fought',
#   'flesh'],
#  ['she',
#   'sucked',
#   'mouthful',
#   'frigid',
#   'air',
#   'varamyr',
#   'half',
#   'heartbeat',
#   'glory',
#   'taste',
#   'strength',
#   'young',
#   'body',
#   'teeth',
#   'snapped',
#   'together',
#   'filled',
#   'mouth',
#   'blood'],
#  ['she', 'raised', 'hands', 'face'],
#  ['he', 'tried', 'push', 'hands', 'would', 'obey', 'clawing', 'eyes'],
#  ['abomination', 'remembered', 'drowning', 'blood', 'pain', 'madness'],
#  ['when', 'tried', 'scream', 'spat', 'tongue'],
#  ['the', 'white', 'world', 'turned', 'fell', 'away'],
#  ['for',
#   'moment',
#   'inside',
#   'weirwood',
#   'gazing',
#   'carved',
#   'red',
#   'eyes',
#   'dying',
#   'man',
#   'twitched',
#   'feebly',
#   'ground',
#   'madwoman',
#   'danced',
#   'blind',
#   'bloody',
#   'underneath',
#   'moon',
#   'weeping',
#   'red',
#   'tears',
#   'ripping',
#   'clothes'],
#  ['then', 'gone', 'rising', 'melting', 'spirit', 'borne', 'cold', 'wind'],
#  ['he', 'snow', 'clouds', 'sparrow', 'squirrel', 'oak'],
#  ['horned',
#   'owl',
#   'flew',
#   'silently',
#   'trees',
#   'hunting',
#   'hare',
#   'varamyr',
#   'inside',
#   'owl',
#   'inside',
#   'hare',
#   'inside',
#   'trees'],
#  ['deep',
#   'frozen',
#   'ground',
#   'earthworms',
#   'burrowed',
#   'blindly',
#   'dark',
#   'well'],
#  ['wood', 'everything', 'that', 'thought', 'exulting'],
#  ['hundred', 'ravens', 'took', 'air', 'cawing', 'felt', 'pass'],
#  ['great', 'elk', 'trumpeted', 'unsettling', 'children', 'clinging', 'back'],
#  ['sleeping', 'direwolf', 'raised', 'head', 'snarl', 'empty', 'air'],
#  ['before',
#   'hearts',
#   'could',
#   'beat',
#   'passed',
#   'searching',
#   'one',
#   'eye',
#   'sly',
#   'stalker',
#   'pack'],
#  ['his', 'wolves', 'would', 'save', 'told'],
#  ['that', 'last', 'thought', 'man'],
#  ['true',
#   'death',
#   'came',
#   'suddenly',
#   'felt',
#   'shock',
#   'cold',
#   'plunged',
#   'icy',
#   'waters',
#   'frozen',
#   'lake'],
#  ['then',
#   'found',
#   'rushing',
#   'moonlit',
#   'snows',
#   'packmates',
#   'close',
#   'behind'],
#  ['half', 'world', 'dark'],
#  ['one', 'eye', 'knew'],
#  ['he', 'bayed', 'sly', 'stalker', 'gave', 'echo'],
#  ['when', 'reached', 'crest', 'wolves', 'paused'],
#  ['thistle',
#   'remembered',
#   'part',
#   'grieved',
#   'lost',
#   'another',
#   'part',
#   'he',
#   'done'],
#  ['below', 'world', 'turned', 'ice'],
#  ['fingers', 'frost', 'crept', 'slowly', 'weirwood', 'reaching'],
#  ['the', 'empty', 'village', 'longer', 'empty'],
#  ['blue', 'eyed', 'shadows', 'walked', 'amongst', 'mounds', 'snow'],
#  ['some',
#   'wore',
#   'brown',
#   'wore',
#   'black',
#   'naked',
#   'flesh',
#   'gone',
#   'white',
#   'snow'],
#  ['wind',
#   'sighing',
#   'hills',
#   'heavy',
#   'scents',
#   'dead',
#   'flesh',
#   'dry',
#   'blood',
#   'skins',
#   'stank',
#   'mold',
#   'rot',
#   'urine'],
#  ['sly', 'gave', 'growl', 'bared', 'teeth', 'ruff', 'bristling'],
#  ['not', 'men'],
#  ['not', 'prey'],
#  ['not'],
#  ['the', 'things', 'moved', 'live'],
#  ['one', 'one', 'raised', 'heads', 'toward', 'three', 'wolves', 'hill'],
#  ['the', 'last', 'look', 'thing', 'thistle'],
#  ['she',
#   'wore',
#   'wool',
#   'fur',
#   'leather',
#   'wore',
#   'coat',
#   'hoarfrost',
#   'crackled',
#   'moved',
#   'glistened',
#   'moonlight'],
#  ['pale',
#   'pink',
#   'icicles',
#   'hung',
#   'fingertips',
#   'ten',
#   'long',
#   'knives',
#   'frozen',
#   'blood'],
#  ['and',
#   'pits',
#   'eyes',
#   'pale',
#   'blue',
#   'light',
#   'flickering',
#   'lending',
#   'coarse',
#   'features',
#   'eerie',
#   'beauty',
#   'never',
#   'known',
#   'life'],
#  ['she', 'sees'],
#  ['tyrion', 'he', 'drank', 'way', 'across', 'narrow', 'sea'],
#  ['the',
#   'ship',
#   'small',
#   'cabin',
#   'smaller',
#   'captain',
#   'would',
#   'allow',
#   'abovedecks'],
#  ['the',
#   'rocking',
#   'deck',
#   'beneath',
#   'feet',
#   'made',
#   'stomach',
#   'heave',
#   'wretched',
#   'food',
#   'tasted',
#   'even',
#   'worse',
#   'retched',
#   'back'],
#  ['but',
#   'need',
#   'salt',
#   'beef',
#   'hard',
#   'cheese',
#   'bread',
#   'crawling',
#   'worms',
#   'wine',
#   'nourish'],
#  ['it', 'red', 'sour', 'strong'],
#  ['sometimes', 'heaved', 'wine', 'always'],
#  ['the', 'world', 'full', 'wine', 'muttered', 'dankness', 'cabin'],
#  ['his', 'father', 'never', 'use', 'drunkards', 'matter'],
#  ['his', 'father', 'dead'],
#  ['he', 'killed'],
#  ['bolt', 'belly', 'lord'],
#  ['if',
#   'better',
#   'crossbow',
#   'would',
#   'put',
#   'cock',
#   'made',
#   'bloody',
#   'bastard'],
#  ['belowdecks', 'neither', 'night', 'day'],
#  ['tyrion',
#   'marked',
#   'time',
#   'comings',
#   'goings',
#   'cabin',
#   'boy',
#   'brought',
#   'meals',
#   'eat'],
#  ['the', 'boy', 'always', 'brought', 'brush', 'bucket', 'clean'],
#  ['is', 'dornish', 'wine', 'tyrion', 'asked', 'pulled', 'stopper', 'skin'],
#  ['it', 'reminds', 'certain', 'snake', 'knew'],
#  ['droll',
#   'fellow',
#   'till',
#   'mountain',
#   'fell',
#   'him',
#   'the',
#   'cabin',
#   'boy',
#   'answer'],
#  ['he',
#   'ugly',
#   'boy',
#   'though',
#   'admittedly',
#   'comely',
#   'certain',
#   'dwarf',
#   'half',
#   'nose',
#   'scar',
#   'eye',
#   'chin'],
#  ['have', 'offended', 'tyrion', 'asked', 'boy', 'scrubbing'],
#  ['were', 'commanded', 'talk'],
#  ['or', 'dwarf', 'diddle', 'mother', 'that', 'went', 'unanswered'],
#  ['where', 'sailing'],
#  ['tell',
#   'that',
#   'jaime',
#   'made',
#   'mention',
#   'free',
#   'cities',
#   'never',
#   'said',
#   'one'],
#  ['is', 'braavos'],
#  ['tyrosh'],
#  ['myr', 'tyrion', 'would', 'sooner', 'gone', 'dorne'],
#  ['myrcella', 'older', 'tommen', 'dornish', 'law', 'iron', 'throne'],
#  ['help', 'claim', 'rights', 'prince', 'oberyn', 'suggested'],
#  ['oberyn',
#   'dead',
#   'though',
#   'head',
#   'smashed',
#   'bloody',
#   'ruin',
#   'armored',
#   'fist',
#   'ser',
#   'gregor',
#   'clegane'],
#  ['and',
#   'without',
#   'red',
#   'viper',
#   'urge',
#   'would',
#   'doran',
#   'martell',
#   'even',
#   'consider',
#   'chancy',
#   'scheme'],
#  ['he',
#   'might',
#   'clap',
#   'chains',
#   'instead',
#   'hand',
#   'back',
#   'sweet',
#   'sister'],
#  ['the', 'wall', 'might', 'safer'],
#  ['old',
#   'bear',
#   'mormont',
#   'said',
#   'night',
#   'watch',
#   'need',
#   'men',
#   'like',
#   'tyrion'],
#  ['mormont', 'might', 'dead', 'though'],
#  ['by', 'slynt', 'may', 'lord', 'commander'],
#  ['that', 'butcher', 'son', 'like', 'forgotten', 'sent', 'wall'],
#  ['do',
#   'really',
#   'want',
#   'spend',
#   'rest',
#   'life',
#   'eating',
#   'salt',
#   'beef',
#   'porridge',
#   'murderers',
#   'thieves'],
#  ['not', 'rest', 'life', 'would', 'last', 'long'],
#  ['janos', 'slynt', 'would', 'see'],
#  ['the', 'cabin', 'boy', 'wet', 'brush', 'scrubbed', 'manfully'],
#  ['have', 'ever', 'visited', 'pleasure', 'houses', 'lys', 'dwarf', 'inquired'],
#  ['might',
#   'whores',
#   'go',
#   'tyrion',
#   'could',
#   'seem',
#   'recall',
#   'valyrian',
#   'word',
#   'whore',
#   'case',
#   'late'],
#  ['the', 'boy', 'tossed', 'brush', 'back', 'bucket', 'took', 'leave'],
#  ['the', 'wine', 'blurred', 'wits'],
#  ['he',
#   'learned',
#   'read',
#   'high',
#   'valyrian',
#   'maester',
#   'knee',
#   'though',
#   'spoke',
#   'nine',
#   'free',
#   'cities',
#   'well',
#   'much',
#   'dialect',
#   'nine',
#   'dialects',
#   'way',
#   'becoming',
#   'separate',
#   'tongues'],
#  ['tyrion', 'braavosi', 'smattering', 'myrish'],
#  ['in',
#   'tyrosh',
#   'able',
#   'curse',
#   'gods',
#   'call',
#   'man',
#   'cheat',
#   'order',
#   'ale',
#   'thanks',
#   'sellsword',
#   'known',
#   'rock'],
#  ['at', 'least', 'dorne', 'speak', 'common', 'tongue'],
#  ['like',
#   'dornish',
#   'food',
#   'dornish',
#   'law',
#   'dornish',
#   'speech',
#   'spiced',
#   'flavors',
#   'rhoyne',
#   'man',
#   'could',
#   'comprehend'],
#  ['dorne', 'yes', 'dorne'],
#  ['he', 'crawled', 'bunk', 'clutching', 'thought', 'like', 'child', 'doll'],
#  ['sleep', 'never', 'come', 'easily', 'tyrion', 'lannister'],
#  ['aboard',
#   'ship',
#   'seldom',
#   'came',
#   'though',
#   'time',
#   'time',
#   'managed',
#   'drink',
#   'sufficient',
#   'wine',
#   'pass'],
#  ['at', 'least', 'dream'],
#  ['he', 'dreamed', 'enough', 'one', 'small', 'life'],
#  ['and', 'follies', 'love', 'justice', 'friendship', 'glory'],
#  ['as', 'well', 'dream', 'tall'],
#  ['it', 'beyond', 'reach', 'tyrion', 'knew'],
#  ['but', 'know', 'whores', 'go'],
#  ['wherever', 'whores', 'go', 'father', 'said'],
#  ['his', 'last', 'words', 'words'],
#  ['the',
#   'crossbow',
#   'thrummed',
#   'lord',
#   'tywin',
#   'sat',
#   'back',
#   'tyrion',
#   'lannister',
#   'found',
#   'waddling',
#   'darkness',
#   'varys',
#   'side'],
#  ['he',
#   'must',
#   'clambered',
#   'back',
#   'shaft',
#   'two',
#   'hundred',
#   'thirty',
#   'rungs',
#   'orange',
#   'embers',
#   'glowed',
#   'mouth',
#   'iron',
#   'dragon'],
#  ['he', 'remembered', 'none'],
#  ['only', 'sound', 'crossbow', 'made', 'stink', 'father', 'bowels', 'opening'],
#  ['even', 'dying', 'found', 'way', 'shit'],
#  ['varys',
#   'escorted',
#   'tunnels',
#   'never',
#   'spoke',
#   'emerged',
#   'beside',
#   'blackwater',
#   'tyrion',
#   'famous',
#   'victory',
#   'lost',
#   'nose'],
#  ['that',
#   'dwarf',
#   'turned',
#   'eunuch',
#   'said',
#   've',
#   'killed',
#   'father',
#   'tone',
#   'man',
#   'might',
#   'use',
#   'say',
#   've',
#   'stubbed',
#   'toe',
#   'the',
#   'master',
#   'whisperers',
#   'dressed',
#   'begging',
#   'brother',
#   'moth',
#   'eaten',
#   'robe',
#   'brown',
#   'roughspun',
#   'cowl',
#   'shadowed',
#   'smooth',
#   'fat',
#   'cheeks',
#   'bald',
#   'round',
#   'head'],
#  ['you', 'climbed', 'ladder', 'said', 'reproachfully'],
#  ['wherever', 'whores', 'go', 'tyrion', 'warned', 'father', 'say', 'word'],
#  ['if', 'loosed', 'would', 'seen', 'threats', 'empty'],
#  ['he', 'would', 'taken', 'crossbow', 'hands', 'took', 'tysha', 'arms'],
#  ['he', 'rising', 'killed'],
#  ['killed', 'shae', 'confessed', 'varys'],
#  ['you', 'knew', 'was'],
#  ['but', 'never', 'knew', 'was', 'varys', 'tittered'],
#  ['and', 'do', 'killed', 'eunuch', 'well'],
#  ['little', 'blood', 'hands', 'would', 'matter'],
#  ['he', 'could', 'say', 'stayed', 'dagger'],
#  ['not', 'gratitude'],
#  ['varys', 'saved', 'headsman', 'sword', 'jaime', 'compelled'],
#  ['jaime', 'better', 'think', 'jaime'],
#  ['he',
#   'found',
#   'fresh',
#   'skin',
#   'wine',
#   'instead',
#   'sucked',
#   'woman',
#   'breast'],
#  ['the',
#   'sour',
#   'red',
#   'ran',
#   'chin',
#   'soaked',
#   'soiled',
#   'tunic',
#   'one',
#   'wearing',
#   'cell'],
#  ['the',
#   'deck',
#   'swaying',
#   'beneath',
#   'feet',
#   'tried',
#   'rise',
#   'lifted',
#   'sideways',
#   'smashed',
#   'hard',
#   'bulkhead'],
#  ['storm', 'realized', 'else', 'even', 'drunker', 'knew'],
#  ['he', 'retched', 'wine', 'lay', 'wondering', 'ship', 'would', 'sink'],
#  ['is', 'vengeance', 'father'],
#  ['has', 'father', 'above', 'made', 'hand'],
#  ['such', 'wages', 'kinslayer', 'said', 'wind', 'howled', 'outside'],
#  ['it',
#   'seem',
#   'fair',
#   'drown',
#   'cabin',
#   'boy',
#   'captain',
#   'rest',
#   'something',
#   'done',
#   'gods',
#   'ever',
#   'fair'],
#  ['and', 'around', 'darkness', 'gulped'],
#  ['when',
#   'stirred',
#   'head',
#   'felt',
#   'like',
#   'burst',
#   'ship',
#   'spinning',
#   'round',
#   'dizzy',
#   'circles',
#   'though',
#   'captain',
#   'insisting',
#   'they',
#   'come',
#   'port'],
#  ['tyrion',
#   'told',
#   'quiet',
#   'kicked',
#   'feebly',
#   'huge',
#   'bald',
#   'sailor',
#   'tucked',
#   'one',
#   'arm',
#   'carried',
#   'squirming',
#   'hold',
#   'empty',
#   'wine',
#   'cask',
#   'awaited'],
#  ['it', 'squat', 'little', 'cask', 'tight', 'fit', 'even', 'dwarf'],
#  ['tyrion', 'pissed', 'struggles', 'good'],
#  ['he', 'crammed', 'face', 'first', 'cask', 'knees', 'pushed', 'ears'],
#  ['the',
#   'stub',
#   'nose',
#   'itched',
#   'horribly',
#   'arms',
#   'pinned',
#   'tightly',
#   'could',
#   'reach',
#   'scratch'],
# ...
#   'dark',
#   'blue',
#   'veins'],
#  ['that',
#   'kind',
#   'no',
#   'tyrion',
#   'eased',
#   'mushroom',
#   'back',
#   'lake',
#   'butter',
#   'emerged'],
#  ['you', 'suspicious', 'illyrio', 'smiled', 'forked', 'yellow', 'beard'],
#  ['oiled',
#   'every',
#   'morning',
#   'make',
#   'gleam',
#   'like',
#   'gold',
#   'tyrion',
#   'suspected'],
#  ['are', 'craven'],
#  ['heard',
#   'you',
#   'in',
#   'seven',
#   'kingdoms',
#   'considered',
#   'grave',
#   'breach',
#   'hospitality',
#   'poison',
#   'guest',
#   'supper',
#   'here',
#   'well',
#   'illyrio',
#   'mopatis',
#   'reached',
#   'wine',
#   'cup'],
#  ['yet',
#   'guest',
#   'plainly',
#   'wishes',
#   'end',
#   'life',
#   'host',
#   'must',
#   'oblige',
#   'he',
#   'took',
#   'gulp'],
#  ['magister', 'ordello', 'poisoned', 'mushroom', 'half', 'year', 'ago'],
#  ['the', 'pain', 'much', 'told'],
#  ['some', 'cramping', 'gut', 'sudden', 'ache', 'behind', 'eyes', 'done'],
#  ['better', 'mushroom', 'sword', 'neck'],
#  ['why',
#   'die',
#   'taste',
#   'blood',
#   'mouth',
#   'could',
#   'butter',
#   'garlic',
#   'the',
#   'dwarf',
#   'studied',
#   'dish'],
#  ['the', 'smell', 'garlic', 'butter', 'mouth', 'watering'],
#  ['some', 'part', 'wanted', 'mushrooms', 'even', 'knowing'],
#  ['he',
#   'brave',
#   'enough',
#   'take',
#   'cold',
#   'steel',
#   'belly',
#   'bite',
#   'mushroom',
#   'would',
#   'hard'],
#  ['that', 'frightened', 'could', 'say'],
#  ['you', 'mistake', 'heard', 'say'],
#  ['is'],
#  ['wonder'],
#  ['if',
#   'would',
#   'sooner',
#   'drown',
#   'wine',
#   'say',
#   'word',
#   'shall',
#   'done',
#   'quickly'],
#  ['drowning',
#   'cup',
#   'cup',
#   'wastes',
#   'time',
#   'wine',
#   'both',
#   'you',
#   'mistake',
#   'tyrion',
#   'said',
#   'loudly'],
#  ['the',
#   'buttered',
#   'mushrooms',
#   'glistened',
#   'lamplight',
#   'dark',
#   'inviting'],
#  ['wish', 'die', 'promise'],
#  ['his', 'voice', 'trailed', 'uncertainty'],
#  ['what'],
#  ['life', 'live'],
#  ['work'],
#  ['children', 'raise', 'lands', 'rule', 'woman', 'love'],
#  ['you',
#   'nothing',
#   'finished',
#   'magister',
#   'illyrio',
#   'but',
#   'change',
#   'that',
#   'he',
#   'plucked',
#   'mushroom',
#   'butter',
#   'chewed',
#   'lustily'],
#  ['delicious', 'the', 'mushrooms', 'poisoned', 'tyrion', 'irritated'],
#  ['no'],
#  ['why', 'wish', 'ill', 'magister', 'illyrio', 'ate', 'another'],
#  ['we', 'must', 'show', 'little', 'trust'],
#  ['come', 'eat', 'he', 'clapped', 'hands'],
#  ['we', 'work'],
#  ['my',
#   'little',
#   'friend',
#   'must',
#   'keep',
#   'strength',
#   'up',
#   'the',
#   'serving',
#   'men',
#   'brought',
#   'heron',
#   'stuffed',
#   'figs',
#   'veal',
#   'cutlets',
#   'blanched',
#   'almond',
#   'milk',
#   'creamed',
#   'herring',
#   'candied',
#   'onions',
#   'foul',
#   'smelling',
#   'cheeses',
#   'plates',
#   'snails',
#   'sweetbreads',
#   'black',
#   'swan',
#   'plumage'],
#  ['tyrion', 'refused', 'swan', 'reminded', 'supper', 'sister'],
#  ['he', 'helped', 'heron', 'herring', 'though', 'sweet', 'onions'],
#  ['and', 'serving', 'men', 'filled', 'wine', 'cup', 'anew', 'time', 'emptied'],
#  ['you',
#   'drink',
#   'deal',
#   'wine',
#   'little',
#   'man',
#   'kinslaying',
#   'dry',
#   'work'],
#  ['it',
#   'gives',
#   'man',
#   'thirst',
#   'the',
#   'fat',
#   'man',
#   'eyes',
#   'glittered',
#   'like',
#   'gemstones',
#   'fingers'],
#  ['there',
#   'westeros',
#   'would',
#   'say',
#   'killing',
#   'lord',
#   'lannister',
#   'merely',
#   'good',
#   'beginning',
#   'they',
#   'best',
#   'say',
#   'sister',
#   'hearing',
#   'find',
#   'short',
#   'tongue',
#   'the',
#   'dwarf',
#   'tore',
#   'loaf',
#   'bread',
#   'half'],
#  ['and', 'best', 'careful', 'say', 'family', 'magister'],
#  ['kinslayer',
#   'lion',
#   'still',
#   'that',
#   'seemed',
#   'amuse',
#   'lord',
#   'cheese',
#   'end'],
#  ['he', 'slapped', 'meaty', 'thigh', 'said', 'you', 'westerosi'],
#  ['you',
#   'sew',
#   'beast',
#   'upon',
#   'scrap',
#   'silk',
#   'suddenly',
#   'lions',
#   'dragons',
#   'eagles'],
#  ['take', 'real', 'lion', 'little', 'friend'],
#  ['the', 'prince', 'keeps', 'pride', 'menagerie'],
#  ['would',
#   'like',
#   'share',
#   'cage',
#   'the',
#   'lords',
#   'seven',
#   'kingdoms',
#   'make',
#   'rather',
#   'much',
#   'sigils',
#   'tyrion',
#   'admit'],
#  ['very', 'well', 'conceded'],
#  ['lannister', 'lion'],
#  ['yet',
#   'still',
#   'father',
#   'son',
#   'jaime',
#   'cersei',
#   'mine',
#   'kill',
#   'how',
#   'odd',
#   'mention',
#   'fair',
#   'sister',
#   'said',
#   'illyrio',
#   'snails'],
#  ['the',
#   'queen',
#   'offered',
#   'lordship',
#   'man',
#   'brings',
#   'head',
#   'matter',
#   'humble',
#   'birth',
#   'it',
#   'tyrion',
#   'expected'],
#  ['if', 'mean', 'take', 'make', 'spread', 'legs', 'well'],
#  ['the',
#   'best',
#   'part',
#   'best',
#   'part',
#   'that',
#   'fair',
#   'trade',
#   'would',
#   'sooner',
#   'mine',
#   'weight',
#   'gold',
#   'the',
#   'cheesemonger',
#   'laughed',
#   'hard',
#   'tyrion',
#   'feared',
#   'rupture'],
#  ['all',
#   'gold',
#   'casterly',
#   'rock',
#   'the',
#   'gold',
#   'grant',
#   'dwarf',
#   'said',
#   'relieved',
#   'drown',
#   'gout',
#   'half',
#   'digested',
#   'eels',
#   'sweetmeats',
#   'but',
#   'rock',
#   'mine',
#   'just',
#   'so',
#   'the',
#   'magister',
#   'covered',
#   'mouth',
#   'belched',
#   'mighty',
#   'belch'],
#  ['do', 'think', 'king', 'stannis', 'give'],
#  ['told', 'great', 'one', 'law'],
#  ['your',
#   'brother',
#   'wears',
#   'white',
#   'cloak',
#   'heir',
#   'laws',
#   'westeros',
#   'stannis',
#   'might',
#   'well',
#   'grant',
#   'casterly',
#   'rock',
#   'said',
#   'tyrion',
#   'but',
#   'small',
#   'matter',
#   'regicide',
#   'kinslaying'],
#  ['for', 'would', 'shorten', 'head', 'short', 'enough', 'stand'],
#  ['but',
#   'would',
#   'think',
#   'mean',
#   'join',
#   'lord',
#   'stannis',
#   'why',
#   'else',
#   'would',
#   'go',
#   'wall',
#   'stannis',
#   'wall',
#   'tyrion',
#   'rubbed',
#   'nose'],
#  ['what',
#   'seven',
#   'bloody',
#   'hells',
#   'stannis',
#   'wall',
#   'shivering',
#   'would',
#   'think'],
#  ['it', 'warmer', 'dorne'],
#  ['perhaps',
#   'sailed',
#   'way',
#   'tyrion',
#   'beginning',
#   'suspect',
#   'certain',
#   'freckled',
#   'washerwoman',
#   'knew',
#   'common',
#   'speech',
#   'pretended'],
#  ['my', 'niece', 'myrcella', 'dorne', 'happens'],
#  ['and',
#   'half',
#   'mind',
#   'make',
#   'queen',
#   'illyrio',
#   'smiled',
#   'serving',
#   'men',
#   'spooned',
#   'bowls',
#   'black',
#   'cherries',
#   'sweet',
#   'cream'],
#  ['what',
#   'poor',
#   'child',
#   'done',
#   'would',
#   'wish',
#   'dead',
#   'even',
#   'kinslayer',
#   'required',
#   'slay',
#   'kin',
#   'said',
#   'tyrion',
#   'wounded'],
#  ['queen', 'said'],
#  ['not', 'kill', 'her', 'the', 'cheesemonger', 'spooned', 'cherries'],
#  ['in', 'volantis', 'use', 'coin', 'crown', 'one', 'face', 'death', 'head'],
#  ['yet', 'coin'],
#  ['to', 'queen', 'kill'],
#  ['dorne', 'might', 'rise', 'myrcella', 'dorne', 'alone', 'enough'],
#  ['if',
#   'clever',
#   'friend',
#   'insists',
#   'know',
#   'this',
#   'tyrion',
#   'looked',
#   'fat',
#   'man',
#   'new',
#   'interest'],
#  ['he', 'right', 'counts'],
#  ['to', 'queen', 'kill'],
#  ['and', 'knew'],
#  ['futile', 'gestures', 'remain'],
#  ['this',
#   'one',
#   'would',
#   'make',
#   'sister',
#   'weep',
#   'bitter',
#   'tears',
#   'least',
#   'magister',
#   'illyrio',
#   'wiped',
#   'sweet',
#   'cream',
#   'mouth',
#   'back',
#   'fat',
#   'hand'],
#  ['the', 'road', 'casterly', 'rock', 'go', 'dorne', 'little', 'friend'],
#  ['nor', 'run', 'beneath', 'wall'],
#  ['yet',
#   'road',
#   'tell',
#   'you',
#   'attainted',
#   'traitor',
#   'regicide',
#   'kinslayer',
#   'this',
#   'talk',
#   'roads',
#   'annoyed'],
#  ['does', 'think', 'game'],
#  ['what', 'one', 'king', 'another', 'may', 'undo'],
#  ['in', 'pentos', 'prince', 'friend'],
#  ['he',
#   'presides',
#   'ball',
#   'feast',
#   'rides',
#   'city',
#   'palanquin',
#   'ivory',
#   'gold'],
#  ['three',
#   'heralds',
#   'go',
#   'golden',
#   'scales',
#   'trade',
#   'iron',
#   'sword',
#   'war',
#   'silver',
#   'scourge',
#   'justice'],
#  ['on',
#   'first',
#   'day',
#   'new',
#   'year',
#   'must',
#   'deflower',
#   'maid',
#   'fields',
#   'maid',
#   'seas',
#   'illyrio',
#   'leaned',
#   'forward',
#   'elbows',
#   'table'],
#  ['yet',
#   'crop',
#   'fail',
#   'war',
#   'lost',
#   'cut',
#   'throat',
#   'appease',
#   'gods',
#   'choose',
#   'new',
#   'prince',
#   'amongst',
#   'forty',
#   'families',
#   'remind',
#   'never',
#   'become',
#   'prince',
#   'pentos',
#   'are',
#   'seven',
#   'kingdoms',
#   'different'],
#  ['there', 'peace', 'westeros', 'justice', 'faith', 'soon', 'enough', 'food'],
#  ['when',
#   'men',
#   'starving',
#   'sick',
#   'fear',
#   'look',
#   'savior',
#   'they',
#   'may',
#   'look',
#   'find',
#   'stannis',
#   'not',
#   'stannis'],
#  ['nor', 'myrcella', 'the', 'yellow', 'smile', 'widened'],
#  ['another'],
#  ['stronger',
#   'tommen',
#   'gentler',
#   'stannis',
#   'better',
#   'claim',
#   'girl',
#   'myrcella'],
#  ['savior',
#   'come',
#   'across',
#   'sea',
#   'bind',
#   'wounds',
#   'bleeding',
#   'westeros',
#   'fine',
#   'words',
#   'tyrion',
#   'unimpressed'],
#  ['words', 'wind'],
#  ['who',
#   'bloody',
#   'savior',
#   'dragon',
#   'the',
#   'cheesemonger',
#   'saw',
#   'look',
#   'face',
#   'laughed'],
#  ['dragon',
#   'three',
#   'heads',
#   'daenerys',
#   'she',
#   'could',
#   'hear',
#   'dead',
#   'man',
#   'coming',
#   'steps'],
#  ['the',
#   'slow',
#   'measured',
#   'sound',
#   'footsteps',
#   'went',
#   'echoing',
#   'amongst',
#   'purple',
#   'pillars',
#   'hall'],
#  ['daenerys',
#   'targaryen',
#   'awaited',
#   'upon',
#   'ebon',
#   'bench',
#   'made',
#   'throne'],
#  ['her', 'eyes', 'soft', 'sleep', 'silver', 'gold', 'hair', 'tousled'],
#  ['your',
#   'grace',
#   'said',
#   'ser',
#   'barristan',
#   'selmy',
#   'lord',
#   'commander',
#   'queensguard',
#   'there',
#   'need',
#   'see',
#   'this',
#   'he',
#   'died',
#   'me',
#   'dany',
#   'clutched',
#   'lion',
#   'pelt',
#   'chest'],
#  ['underneath', 'sheer', 'white', 'linen', 'tunic', 'covered', 'midthigh'],
#  ['she', 'dreaming', 'house', 'red', 'door', 'missandei', 'woke'],
#  ['there', 'time', 'dress'],
#  ['khaleesi', 'whispered', 'irri', 'you', 'must', 'touch', 'dead', 'man'],
#  ['it',
#   'bad',
#   'luck',
#   'touch',
#   'dead',
#   'unless',
#   'killed',
#   'yourself',
#   'jhiqui',
#   'bigger',
#   'boned',
#   'irri',
#   'wide',
#   'hips',
#   'heavy',
#   'breasts'],
#  ['that', 'known', 'it', 'known', 'irri', 'agreed'],
#  ['dothraki',
#   'wise',
#   'horses',
#   'concerned',
#   'could',
#   'utter',
#   'fools',
#   'much',
#   'else'],
#  ['they', 'girls', 'besides'],
#  ['her',
#   'handmaids',
#   'age',
#   'her',
#   'women',
#   'grown',
#   'look',
#   'black',
#   'hair',
#   'copper',
#   'skin',
#   'almond',
#   'shaped',
#   'eyes',
#   'girls'],
#  ['they', 'given', 'wed', 'khal', 'drogo'],
#  ['it',
#   'drogo',
#   'given',
#   'pelt',
#   'wore',
#   'head',
#   'hide',
#   'hrakkar',
#   'white',
#   'lion',
#   'dothraki',
#   'sea'],
#  ['it',
#   'big',
#   'musty',
#   'smell',
#   'made',
#   'feel',
#   'sun',
#   'and',
#   'stars',
#   'still',
#   'near'],
#  ['grey', 'worm', 'appeared', 'atop', 'steps', 'first', 'torch', 'hand'],
#  ['his', 'bronze', 'cap', 'crested', 'three', 'spikes'],
#  ['behind',
#   'followed',
#   'four',
#   'unsullied',
#   'bearing',
#   'dead',
#   'man',
#   'shoulders'],
#  ['their',
#   'caps',
#   'one',
#   'spike',
#   'faces',
#   'showed',
#   'little',
#   'might',
#   'cast',
#   'bronze',
#   'well'],
#  ['they', 'laid', 'corpse', 'feet'],
#  ['ser', 'barristan', 'pulled', 'back', 'bloodstained', 'shroud'],
#  ['grey', 'worm', 'lowered', 'torch', 'might', 'see'],
#  ['the',
#   'dead',
#   'man',
#   'face',
#   'smooth',
#   'hairless',
#   'though',
#   'cheeks',
#   'slashed',
#   'open',
#   'ear',
#   'ear'],
#  ['he', 'tall', 'man', 'blue', 'eyed', 'fair', 'face'],
#  ['some',
#   'child',
#   'lys',
#   'old',
#   'volantis',
#   'snatched',
#   'ship',
#   'corsairs',
#   'sold',
#   'bondage',
#   'red',
#   'astapor'],
#  ['though', 'eyes', 'open', 'wounds', 'wept'],
#  ['there', 'wounds', 'could', 'count'],
#  ['your',
#   'grace',
#   'ser',
#   'barristan',
#   'said',
#   'there',
#   'harpy',
#   'drawn',
#   'bricks',
#   'alley',
#   'found',
#   'drawn',
#   'blood',
#   'daenerys',
#   'knew',
#   'way'],
#  ['the', 'sons', 'harpy', 'butchery', 'night', 'kill', 'left', 'mark'],
#  ['grey', 'worm', 'man', 'alone'],
#  ['had',
#   'partner',
#   'by',
#   'command',
#   'unsullied',
#   'walked',
#   'streets',
#   'meereen',
#   'night',
#   'always',
#   'walked',
#   'pairs'],
#  ['my',
#   'queen',
#   'replied',
#   'captain',
#   'your',
#   'servant',
#   'stalwart',
#   'shield',
#   'duty',
#   'last',
#   'night'],
#  ['he',
#   'gone',
#   'certain',
#   'place',
#   'drink',
#   'companionship',
#   'certain',
#   'place'],
#  ['what', 'mean', 'house', 'pleasure', 'your', 'grace', 'brothel'],
#  ['half',
#   'freedmen',
#   'yunkai',
#   'wise',
#   'masters',
#   'famed',
#   'training',
#   'bedslaves'],
#  ['the', 'way', 'seven', 'sighs'],
#  ['brothels', 'sprouted', 'like', 'mushrooms', 'meereen'],
#  ['it', 'know'],
#  ['they', 'need', 'survive'],
#  ['food',
#   'costly',
#   'every',
#   'day',
#   'whilst',
#   'price',
#   'flesh',
#   'grew',
#   'cheaper'],
#  ['in',
#   'poorer',
#   'districts',
#   'stepped',
#   'pyramids',
#   'meereen',
#   'slaver',
#   'nobility',
#   'brothels',
#   'catering',
#   'every',
#   'conceivable',
#   'erotic',
#   'taste',
#   'knew'],
#  ['even',
#   'what',
#   'could',
#   'eunuch',
#   'hope',
#   'find',
#   'brothel',
#   'even',
#   'lack',
#   'man',
#   'parts',
#   'may',
#   'still',
#   'man',
#   'heart',
#   'your',
#   'grace',
#   'said',
#   'grey',
#   'worm'],
#  ['this',
#   'one',
#   'told',
#   'servant',
#   'stalwart',
#   'shield',
#   'sometimes',
#   'gave',
#   'coin',
#   'women',
#   'brothels',
#   'lie',
#   'hold',
#   'him',
#   'the',
#   'blood',
#   'dragon',
#   'weep'],
#  ['stalwart', 'shield', 'said', 'dry', 'eyed'],
#  ['that',
#   'name',
#   'if',
#   'please',
#   'your',
#   'grace',
#   'it',
#   'fine',
#   'name',
#   'the',
#   'good',
#   'masters',
#   'astapor',
#   'allowed',
#   'slave',
#   'soldiers',
#   'even',
#   'names'],
#  ['some',
#   'unsullied',
#   'reclaimed',
#   'birth',
#   'names',
#   'freed',
#   'others',
#   'chose',
#   'new',
#   'names'],
#  ['is',
#   'known',
#   'many',
#   'attackers',
#   'fell',
#   'upon',
#   'stalwart',
#   'shield',
#   'this',
#   'one',
#   'know'],
#  ['many', 'six', 'said', 'ser', 'barristan'],
#  ['from', 'look', 'wounds', 'swarmed', 'sides'],
#  ['he', 'found', 'empty', 'scabbard'],
#  ['it',
#   'may',
#   'wounded',
#   'attackers',
#   'dany',
#   'said',
#   'silent',
#   'prayer',
#   'somewhere',
#   'one',
#   'harpy',
#   'sons',
#   'dying',
#   'even',
#   'clutching',
#   'belly',
#   'writhing',
#   'pain'],
#  ['why',
#   'cut',
#   'open',
#   'cheeks',
#   'like',
#   'gracious',
#   'queen',
#   'said',
#   'grey',
#   'worm',
#   'his',
#   'killers',
#   'forced',
#   'genitals',
#   'goat',
#   'throat',
#   'servant',
#   'stalwart',
#   'shield'],
#  ['this',
#   'one',
#   'removed',
#   'bringing',
#   'here',
#   'they',
#   'could',
#   'feed',
#   'genitals'],
#  ['the', 'astapori', 'left', 'neither', 'root', 'stem'],
#  ['the', 'sons', 'grow', 'bolder', 'dany', 'observed'],
#  ['until',
#   'limited',
#   'attacks',
#   'unarmed',
#   'freedmen',
#   'cutting',
#   'streets',
#   'breaking',
#   'homes',
#   'cover',
#   'darkness',
#   'murder',
#   'beds'],
#  ['this',
#   'first',
#   'soldiers',
#   'slain',
#   'the',
#   'first',
#   'ser',
#   'barristan',
#   'warned',
#   'but',
#   'last',
#   'still',
#   'war',
#   'dany',
#   'realized',
#   'fighting',
#   'shadows'],
#  ['she', 'hoped', 'respite', 'killing', 'time', 'build', 'heal'],
#  ['shrugging',
#   'lion',
#   'pelt',
#   'knelt',
#   'beside',
#   'corpse',
#   'closed',
#   'dead',
#   'man',
#   'eyes',
#   'ignoring',
#   'jhiqui',
#   'gasp'],
#  ['stalwart', 'shield', 'shall', 'forgotten'],
#  ['have',
#   'washed',
#   'dressed',
#   'battle',
#   'bury',
#   'cap',
#   'shield',
#   'spears',
#   'it',
#   'shall',
#   'your',
#   'grace',
#   'commands',
#   'said',
#   'grey',
#   'worm'],
#  ['send',
#   'men',
#   'temple',
#   'graces',
#   'ask',
#   'man',
#   'come',
#   'blue',
#   'graces',
#   'sword',
#   'wound'],
#  ['and',
#   'spread',
#   'word',
#   'pay',
#   'good',
#   'gold',
#   'short',
#   'sword',
#   'stalwart',
#   'shield'],
#  ['inquire',
#   'butchers',
#   'herdsmen',
#   'learn',
#   'gelding',
#   'goats',
#   'late',
#   'perhaps',
#   'goatherd',
#   'would',
#   'confess'],
#  ['henceforth',
#   'man',
#   'mine',
#   'walks',
#   'alone',
#   'dark',
#   'these',
#   'ones',
#   'shall',
#   'obey',
#   'daenerys',
#   'pushed',
#   'hair',
#   'back'],
#  ['find', 'cowards'],
#  ['find',
#   'might',
#   'teach',
#   'harpy',
#   'sons',
#   'means',
#   'wake',
#   'dragon',
#   'grey',
#   'worm',
#   'saluted'],
#  ['his',
#   'unsullied',
#   'closed',
#   'shroud',
#   'lifted',
#   'dead',
#   'man',
#   'onto',
#   'shoulders',
#   'bore',
#   'hall'],
#  ['ser', 'barristan', 'selmy', 'remained', 'behind'],
#  ['his', 'hair', 'white', 'crow', 'feet', 'corners', 'pale', 'blue', 'eyes'],
#  ['yet',
#   'back',
#   'still',
#   'un',
#   'bent',
#   'years',
#   'yet',
#   'robbed',
#   'skill',
#   'arms'],
#  ...]

# %%
model = gensim.models.Word2Vec(
    window = 7,
    min_count=2,
    workers=8,
    vector_size=200,
    epochs = 10
    )

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (9620326, 10171670)

# %%
len(model.wv["throne"])
# Out:
# 200

# %%
model.wv.most_similar("king")
# Out:
# [('baratheon', 0.5978323817253113),
#  ('realm', 0.5654007792472839),
#  ('feinting', 0.5078660845756531),
#  ('usurper', 0.4950030446052551),
#  ('murdered', 0.4895135462284088),
#  ('tourney', 0.4821915626525879),
#  ('royal', 0.4779691994190216),
#  ('coronation', 0.4761578440666199),
#  ('conqueror', 0.47266194224357605),
#  ('mng', 0.46092548966407776)]

# %%
model.wv.similarity("arya", "sansa")
# Out:
# 0.68034047

# %%
model.wv.similarity("jaime", "sansa")
# Out:
# 0.4821448

# %%
model.wv.doesnt_match("arya jaime daenerys".split())
# Out:
# 'daenerys'
