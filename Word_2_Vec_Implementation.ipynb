# %%
import gensim

# %%
from gensim import downloader

# %%
model = downloader.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model["cricket"]
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
len(model["cricket"])
# Out:
# 300

# %%
from gensim.models import KeyedVectors

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=f102ea9cb8483dbe0df396491d567838e1786169dfa462776f4d0e203c478841
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
model.most_similar("girl")
# Out:
# [('boy', 0.8543271422386169),
#  ('teenage_girl', 0.7927975654602051),
#  ('woman', 0.7494640946388245),
#  ('teenager', 0.7172499299049377),
#  ('schoolgirl', 0.7075953483581543),
#  ('teenaged_girl', 0.6650916337966919),
#  ('daughter', 0.6489864587783813),
#  ('mother', 0.6478164196014404),
#  ('toddler', 0.6473966836929321),
#  ('girls', 0.6154742240905762)]

# %%
model.similarity("cricket","football")
# Out:
# 0.45974636
